# %% [markdown]
# # Projeto - Classificação - Inclusão Financeira na África

# %% [markdown]
# ## Considerações iniciais
#
# A inclusão financeira continua a ser um dos principais obstáculos ao desenvolvimento econômico e humano na África. Por exemplo, no Quênia, Ruanda, Tanzânia e Uganda, apenas 9,1 milhões de adultos (14% dos adultos), têm acesso ou usam uma conta bancária comercial.
#
# Em 2008, o nível de inclusão financeira na África Subsaariana era de pouco mais de 23%. Em 2018, esse número quase dobrou. No Togo, Mazamesso Assih, ministro de finanças, coordena uma estratégia de inclusão financeira com bancos parceiros. Ele afirma que garantir acesso a serviços financeiros básicos para a população, é fundamental para impulsionar a economia Africana.
#
# Em 2022, conforme destacado no último relatório do Banco Central da África Ocidental, atingiu-se uma das mais altas taxas de inclusão financeira da região, próxima de 82%. Uma parcela significativa desse aumento veio do aumento dos serviços financeiros digitais.
#
# Assih afirma também, que existem três razões principais pelas quais as nações africanas devem apostar na inclusão financeira:
#
# **1)** Tornar os serviços financeiros mais acessíveis promove o empoderamento das pessoas mais vulneráveis, especialmente as mulheres.
#
# **2)** Combater redes criminosas, passar de uma economia exclusivamente monetária para uma infraestrutura financeira digital torna mais fácil para as autoridades rastrear transações e lidar com contrabandistas e traficantes.
#
# **3)** impulsionará a conectividade dos setores público e privado para um crescimento sustentável, apoiando as start-ups africanas.

# %% [markdown]
# ## O Problema de Negócio
#
# O objetivo desta competição é criar um modelo de aprendizado de máquina para prever quais indivíduos vão ou não utilizar uma conta bancária. Os modelos e soluções desenvolvidos devem fornecer uma indicação do estado da inclusão financeira no Quênia, Ruanda, Tanzânia e Uganda.

# %% [markdown]
# ## Descrição do dados
#
# Os dados necessários podem ser encontrados no [repositório da atividade](https://www.kaggle.com/c/inclusao-financeira-na-africa). No arquivo *train.csv* você encontrará:
#
#
# - **country**: Pais de Origem.
# - **year**: Ano da Inclusão
# - **uniqueid**: Id do Usuário.
# - **bank_account**: Possui ou Não a Conta no Banco.
# - **location_type**: Tipo de Localidade (Rural...)
# - **cellphone_access**: Possui ou Não Celular.
# - **household_size**: Tamanho da Casa.
# - **age_of_respondent**: Idade do Usuário.
# - **gender_of_respondent**: Gênero do Usuário.
# - **relationship_with_head**: Status com o Dono da Conta.
# - **marital_status**: Situação Civil.
# - **education_level**: Nível de Educação.
# - **job_type**: - Tipo de Trabalho.

# %% [markdown]
# # Etapas do Projeto

# %% [markdown]
# 1. Análise exploratória
# 2. Preparação e limpeza dos dados
# 3. Seleção de atributos
# 4. Construção do modelo
# 5. Avaliação do modelo
# 6. Otimização do modelo

# %% [markdown]
# # Desenvolvimento do Projeto

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error as MSE
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Importando dados

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %% [markdown]
# ## Análise exploratória

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11762 entries, 0 to 11761
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 11762 non-null  object
#  1   year                    11762 non-null  int64
#  2   uniqueid                11762 non-null  object
#  3   location_type           11762 non-null  object
#  4   cellphone_access        11762 non-null  object
#  5   household_size          11762 non-null  int64
#  6   age_of_respondent       11762 non-null  int64
#  7   gender_of_respondent    11762 non-null  object
#  8   relationship_with_head  11762 non-null  object
#  9   marital_status          11762 non-null  object
#  10  education_level         11762 non-null  object
#  11  job_type                11762 non-null  object
#  12  uid                     11762 non-null  object
#  13  bank_account            11762 non-null  object
# dtypes: int64(3), object(11)
# memory usage: 1.3+ MB

# %%
df_train.shape
# 14               7                 37                 Male
# 15               3                 51               Female
# 16               1                 70               Female
# 17               4                 59                 Male
# 18               2                 30               Female
# 19               4                 21               Female
# 20               6                 49                 Male
# 21               4                 43               Female
# 22               3                 50                 Male
# 23               2                 57               Female
# 24               1                 18               Female
# 25               6                 53               Female
# 26               1                 32                 Male
# 27               3                 34               Female
# 28               7                 35               Female
# 29               2                 35               Female
# 30               3                 22               Female
# 31               7                 25               Female
# 32               6                 31               Female
# 33               2                 24                 Male
# 34               6                 39               Female
# 35               8                 35               Female
# 36               1                 41                 Male
# 37               1                 27                 Male
# 38               1                 24                 Male
# 39               4                 39                 Male
# 40               8                 35               Female
# 41               5                 21                 Male
# 42               3                 56                 Male
# 43               8                 19               Female
# 44               2                 50               Female
# 45               3                 46               Female
# 46               3                 23               Female
# 47               2                 35               Female
# 48               1                 42                 Male
# 49               2                 28                 Male
#
#    relationship_with_head           marital_status  \
# 0       Head of Household       Divorced/Seperated
# 1       Head of Household     Single/Never Married
# 2       Head of Household  Married/Living together
# 3       Head of Household  Married/Living together
# 4       Head of Household     Single/Never Married
# 5                  Spouse  Married/Living together
# 6       Head of Household       Divorced/Seperated
# 7       Head of Household  Married/Living together
# 8       Head of Household  Married/Living together
# 9                  Spouse     Single/Never Married
# 10      Head of Household     Single/Never Married
# 11                 Spouse     Single/Never Married
# 12                 Spouse  Married/Living together
# 13      Head of Household  Married/Living together
# 14      Head of Household  Married/Living together
# 15      Head of Household                  Widowed
# 16      Head of Household                  Widowed
# 17      Head of Household  Married/Living together
# 18                 Spouse     Single/Never Married
# 19                  Child     Single/Never Married
# 20      Head of Household  Married/Living together
# 21                 Spouse  Married/Living together
# 22      Head of Household     Single/Never Married
# 23                 Spouse  Married/Living together
# 24      Head of Household       Divorced/Seperated
# 25      Head of Household  Married/Living together
# 26      Head of Household  Married/Living together
# 27      Head of Household  Married/Living together
# 28                 Spouse  Married/Living together
# 29      Head of Household     Single/Never Married
# 30                 Spouse  Married/Living together
# 31                 Spouse  Married/Living together
# 32      Head of Household  Married/Living together
# 33      Head of Household  Married/Living together
# 34                 Spouse  Married/Living together
# 35                 Spouse  Married/Living together
# 36      Head of Household     Single/Never Married
# 37      Head of Household       Divorced/Seperated
# 38      Head of Household     Single/Never Married
# 39      Head of Household  Married/Living together
# 40                 Spouse  Married/Living together
# 41                  Child     Single/Never Married
# 42      Head of Household  Married/Living together
# 43                  Child     Single/Never Married
# 44                 Spouse  Married/Living together
# 45      Head of Household                  Widowed
# 46                 Parent     Single/Never Married
# 47                 Spouse     Single/Never Married
# 48      Head of Household       Divorced/Seperated
# 49      Head of Household     Single/Never Married
#
#                     education_level                   job_type  \
# 0                 Primary education        Farming and Fishing
# 1                 Primary education              Self employed
# 2               Secondary education        Farming and Fishing
# 3                 Primary education        Farming and Fishing
# 4                 Primary education        Informally employed
# 5   Vocational/Specialised training              Self employed
# 6                Tertiary education        Informally employed
# 7                 Primary education        Informally employed
# 8                 Primary education              Self employed
# 9                 Primary education              Self employed
# 10                Primary education              Self employed
# 11              No formal education              Self employed
# 12              No formal education        Farming and Fishing
# 13                Primary education                  No Income
# 14                Primary education        Informally employed
# 15                Primary education        Farming and Fishing
# 16              No formal education               Other Income
# 17  Vocational/Specialised training        Informally employed
# 18              No formal education       Remittance Dependent
# 19              Secondary education       Remittance Dependent
# 20                Primary education        Informally employed
# 21              No formal education        Informally employed
# 22              Secondary education        Informally employed
# 23                Primary education        Farming and Fishing
# 24                Primary education              Self employed
# 25                Primary education  Formally employed Private
# 26                Primary education              Self employed
# 27                Primary education       Remittance Dependent
# 28                Primary education        Farming and Fishing
# 29              Secondary education               Other Income
# 30              No formal education        Informally employed
# 31                Primary education              Self employed
# 32              No formal education        Farming and Fishing
# 33              Secondary education               Other Income
# 34                Primary education        Farming and Fishing
# 35                Primary education        Farming and Fishing
# 36                Primary education        Informally employed
# 37                Primary education  Formally employed Private
# 38                Primary education  Formally employed Private
# 39              Secondary education              Self employed
# 40                Primary education              Self employed
# 41                Primary education        Informally employed
# 42              Secondary education        Farming and Fishing
# 43              Secondary education        Farming and Fishing
# 44              No formal education        Farming and Fishing
# 45                Primary education              Self employed
# 46              Secondary education        Farming and Fishing
# 47                Primary education        Informally employed
# 48                Primary education              Self employed
# 49                Primary education        Informally employed
#
#                        uid bank_account
# 0     Rwanda_uniqueid_4858           No
# 1   Tanzania_uniqueid_3015           No
# 2      Rwanda_uniqueid_103           No
# 3     Rwanda_uniqueid_4582           No
# 4   Tanzania_uniqueid_2854           No
# 5      Kenya_uniqueid_5704           No
# 6   Tanzania_uniqueid_4831           No
# 7   Tanzania_uniqueid_3231           No
# 8      Rwanda_uniqueid_390           No
# 9   Tanzania_uniqueid_4088           No
# 10  Tanzania_uniqueid_6624           No
# 11   Tanzania_uniqueid_325           No
# 12     Rwanda_uniqueid_675           No
# 13    Uganda_uniqueid_1618           No
# 14    Rwanda_uniqueid_2784           No
# 15    Rwanda_uniqueid_7107           No
# 16     Kenya_uniqueid_4792          Yes
# 17     Kenya_uniqueid_4201           No
# 18  Tanzania_uniqueid_6554           No
# 19    Rwanda_uniqueid_2018           No
# 20      Kenya_uniqueid_320           No
# 21    Rwanda_uniqueid_3365           No
# 22  Tanzania_uniqueid_2662           No
# 23    Rwanda_uniqueid_4500           No
# 24  Tanzania_uniqueid_2187           No
# 25    Rwanda_uniqueid_5721           No
# 26     Kenya_uniqueid_5914           No
# 27     Kenya_uniqueid_5615           No
# 28    Rwanda_uniqueid_8674           No
# 29     Kenya_uniqueid_5494          Yes
# 30    Rwanda_uniqueid_3341           No
# 31     Uganda_uniqueid_751           No
# 32      Kenya_uniqueid_331           No
# 33    Rwanda_uniqueid_3911           No
# 34    Rwanda_uniqueid_2937           No
# 35    Rwanda_uniqueid_4103           No
# 36     Kenya_uniqueid_3117          Yes
# 37  Tanzania_uniqueid_5957           No
# 38     Kenya_uniqueid_3332           No
# 39      Kenya_uniqueid_614           No
# 40    Uganda_uniqueid_1925           No
# 41    Rwanda_uniqueid_1512           No
# 42      Kenya_uniqueid_723          Yes
# 43    Rwanda_uniqueid_7103           No
# 44     Kenya_uniqueid_5807           No
# 45      Rwanda_uniqueid_91           No
# 46    Rwanda_uniqueid_7560           No
# 47  Tanzania_uniqueid_3994           No
# 48    Rwanda_uniqueid_4974           No
# 49  Tanzania_uniqueid_1042           No

# %%
df_train.describe()
# Out:
#                year  household_size  age_of_respondent
# count  11762.000000    11762.000000       11762.000000
# mean    2016.983336        3.793913          38.602364
# std        0.848669        2.225423          16.334624
# min     2016.000000        1.000000          16.000000
# 25%     2016.000000        2.000000          26.000000
# 50%     2017.000000        3.000000          35.000000
# 75%     2018.000000        5.000000          48.000000
# max     2018.000000       21.000000         100.000000
